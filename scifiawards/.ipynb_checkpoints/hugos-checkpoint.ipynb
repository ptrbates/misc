# %% [markdown]
# Retrieve the Hugo Awards for Best Novel, Best Novella, Best Novelette, and Best Short Story.
#
# Retrieved from http://www.thehugoawards.org/

# %%
# Import required libraries
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd

# %%
# Ok, let's get links to the years that awards have been given out.
url = "http://www.thehugoawards.org/hugo-history/"

# Save the html from that page
r = requests.get(url)
text = r.text
soup = BeautifulSoup(text, "html.parser")

# Collect the links
links = []
for link in soup.findAll('a'):
    links.append(link.get('href'))
    
pattern = re.compile('http://www.thehugoawards.org/hugo-history/\d+')
pages = []

for link in links:
    try:
        if bool(pattern.search(link)):
                pages.append(link)
    except:
        pass

pages = sorted(list(set(pages)), reverse=True)

# %%
# Write a function to retrieve the finalist entries for a given year and award

def get_hugos(link):
    # Get the html
    r = requests.get(link)
    text = r.text
    pagesoup = BeautifulSoup(text, 'html.parser')

    # Get the year
    year = pagesoup.find_all('title')[0].text[0:4]

    x1 = []
    # Retrieve the information for each type of award
    for award in ['Best Novel', 'Best Novella', 'Best Novelette', 'Best Short Story']:
        # Get the finalist books and authors
        try:
            ul_list = pagesoup.find('strong', text=award).find_next('ul').findAll('li')
            x2 = {}
            x2[award] = []
            for item in ul_list:
                x2[award].append(item.get_text())
        except:
            x2 = {}
        x1.append(x2)
    
    return({year: x1})

# %%
def build_finalists(pages):
    # Build a list of the finalists
    finalists = []
    print('.' * len(pages))

    for link in pages:
        time.sleep(1)
        finalists.append(get_hugos(link))
        print('.', end='')

    return(finalists)

# %%
finalists = build_finalists(pages)
# Out:
# .....................................................................
# ........................

# %%
pattern1 = re.compile(r' by ')
listoflists = []

for d in finalists:
    for year, awards in d.items():
        for entries in awards:
            for award, itemlist in entries.items():
                for item in itemlist:
                    # Skip the item if the item is "No Award"
                    if item == 'No Award':
                        title = 'No Award'
                        auth = 'None'
                        pub = 'None'

                    else:

                        # Get the publishing information
                        if item[-1] == ')':
                            split1 = item.rsplit(' (', maxsplit=1)
                            pub = split1[-1].replace(')', '')
                        elif item[-1] == ']':
                            split1 = item.rsplit(' [', maxsplit=1)
                            pub = split1[-1].replace(']', '')
                        else:
                            split1 = [item, '']
                            pub = 'no publishing information available'
                        
                        # Get the author and title information
                        if bool(pattern1.search(split1[-2])):
                            split2 = split1[-2].rsplit(' by ')
                            auth = split2[-1]
                            title = split2[0]
                        else:
                            split2 = split1[-2].rsplit(', ')
                            auth = split2[-1]
                            title = split2[0]

                    # Grab the finalist position
                    pos = itemlist.index(item) + 1

                    # Append the information to listoflists
                    listoflists.append([year, award, pos, title, auth, pub])

# %%
# Construct a dataframe of the final results
hugos = pd.DataFrame(listoflists, columns=['year', 'award', 'outcome', 'title', 'author', 'published'])
hugos = hugos.drop_duplicates()

hugos.author = [author.lower().replace(r". ", r".").replace(r".", r". ").title() for author in hugos.author]
hugos.title = [title[0:-1] if title[-1] == ',' else title for title in hugos.title ]

# Make the year column numeric
hugos['year'] = pd.to_numeric(hugos['year'])

# Export the dataframe to csv
filename = 'hugos.csv'
hugos.to_csv(filename, index=False)

# %%
hugos
# Out:
#       year             award  placing  \
# 0     2017        Best Novel        1
# 1     2017        Best Novel        2
# 2     2017        Best Novel        3
# 3     2017        Best Novel        4
# 4     2017        Best Novel        5
# 5     2017        Best Novel        6
# 6     2017      Best Novella        1
# 7     2017      Best Novella        2
# 8     2017      Best Novella        3
# 9     2017      Best Novella        4
# 10    2017      Best Novella        5
# 11    2017      Best Novella        6
# 12    2017    Best Novelette        1
# 13    2017    Best Novelette        2
# 14    2017    Best Novelette        3
# 15    2017    Best Novelette        4
# 16    2017    Best Novelette        5
# 17    2017    Best Novelette        6
# 18    2017    Best Novelette        7
# 19    2017  Best Short Story        1
# 20    2017  Best Short Story        2
# 21    2017  Best Short Story        3
# 22    2017  Best Short Story        4
# 23    2017  Best Short Story        5
# 24    2017  Best Short Story        6
# 25    2017  Best Short Story        7
# 26    2016        Best Novel        1
# 27    2016        Best Novel        2
# 28    2016        Best Novel        3
# 29    2016        Best Novel        4
# ...    ...               ...      ...
# 1182  1941      Best Novella        3
# 1183  1941      Best Novella        4
# 1184  1941      Best Novella        5
# 1185  1941    Best Novelette        1
# 1186  1941    Best Novelette        2
# 1187  1941    Best Novelette        3
# 1188  1941    Best Novelette        4
# 1189  1941    Best Novelette        5
# 1190  1941    Best Novelette        6
# 1191  1941  Best Short Story        1
# 1192  1941  Best Short Story        2
# 1193  1941  Best Short Story        3
# 1194  1941  Best Short Story        4
# 1195  1941  Best Short Story        5
# 1196  1939        Best Novel        1
# 1197  1939      Best Novella        1
# 1198  1939      Best Novella        2
# 1199  1939      Best Novella        3
# 1200  1939      Best Novella        4
# 1201  1939      Best Novella        5
# 1202  1939    Best Novelette        1
# 1203  1939    Best Novelette        2
# 1204  1939    Best Novelette        3
# 1205  1939    Best Novelette        4
# 1206  1939    Best Novelette        5
# 1207  1939  Best Short Story        1
# 1208  1939  Best Short Story        2
# 1209  1939  Best Short Story        3
# 1210  1939  Best Short Story        4
# 1211  1939  Best Short Story        5
#
#                                                   title  \
# 0                                      The Obelisk Gate
# 1                              All the Birds in the Sky
# 2                                        Ninefox Gambit
# 3                             A Closed and Common Orbit
# 4                                Too Like the Lightning
# 5                                           Death’s End
# 6                                 Every Heart a Doorway
# 7                        The Dream-Quest of Vellitt Boe
# 8                                 Penric and the Shaman
# 9                               The Ballad of Black Tom
# 10                                     A Taste of Honey
# 11                                    This Census-Taker
# 12                                   “The Tomato Thief”
# 13               “You’ll Surely Drown Here If You Stay”
# 14                             “Touring with the Alien”
# 15                         “The Jewel and Her Lapidary”
